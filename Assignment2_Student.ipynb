# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="Rossum"></p>
#
#
# ____

# %%
import pandas as pd
import numpy as np

# %%
ecom = pd.read_csv('data.csv',encoding= 'unicode_escape')

# %% [markdown]
# **Check the head of the DataFrame.**

# %%
e=ecom
e.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country  Total  \
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom  15.30
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom  20.34
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom  22.00
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom  20.34
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom  20.34
#
#          InvoiceDate2
# 0 2010-12-01 08:26:00
# 1 2010-12-01 08:26:00
# 2 2010-12-01 08:26:00
# 3 2010-12-01 08:26:00
# 4 2010-12-01 08:26:00

# %% [markdown]
# ** How many rows and columns are there? **

# %%
e.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB

# %% [markdown]
# ** Show the statistical measurements of ecom dataset **

# %%
e.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  541909.000000  541909.000000  406829.000000
# mean        9.552250       4.611114   15287.690570
# std       218.081158      96.759853    1713.600303
# min    -80995.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13953.000000
# 50%         3.000000       2.080000   15152.000000
# 75%        10.000000       4.130000   16791.000000
# max     80995.000000   38970.000000   18287.000000

# %% [markdown]
# ** What is the average Purchase Price? **

# %%
e.UnitPrice.mean()
# Out:
# 4.611113626083471

# %% [markdown]
# ** What were the highest and lowest purchase prices? **

# %%
e.UnitPrice.max()
# Out:
# 38970.0

# %%
e.UnitPrice.min()
# Out:
# -11062.06

# %% [markdown]
# ** List the country names and number of records belongs to each country **

# %%
e['Country'].value_counts()
# Out:
# United Kingdom          495478
# Germany                   9495
# France                    8557
# EIRE                      8196
# Spain                     2533
# Netherlands               2371
# Belgium                   2069
# Switzerland               2002
# Portugal                  1519
# Australia                 1259
# Norway                    1086
# Italy                      803
# Channel Islands            758
# Finland                    695
# Cyprus                     622
# Sweden                     462
# Unspecified                446
# Austria                    401
# Denmark                    389
# Japan                      358
# Poland                     341
# Israel                     297
# USA                        291
# Hong Kong                  288
# Singapore                  229
# Iceland                    182
# Canada                     151
# Greece                     146
# Malta                      127
# United Arab Emirates        68
# European Community          61
# RSA                         58
# Lebanon                     45
# Lithuania                   35
# Brazil                      32
# Czech Republic              30
# Bahrain                     19
# Saudi Arabia                10
# Name: Country, dtype: int64

# %% [markdown]
# ** How many records are as Country United Kingdom? **

# %%
e['Country'].value_counts()['United Kingdom']
# Out:
# 495478

# %%
e[e.Country=='United Kingdom'].count()
# Out:
# InvoiceNo      495478
# StockCode      495478
# Description    494024
# Quantity       495478
# InvoiceDate    495478
# UnitPrice      495478
# CustomerID     361878
# Country        495478
# dtype: int64

# %% [markdown]
# ** Create a column named Total which shows the total amount of spend using UnitPrice and Quantity ? **

# %%
e['Total']=e['UnitPrice']*e['Quantity']
e
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country  Total
# 0        12/1/2010 8:26       2.55     17850.0  United Kingdom  15.30
# 1        12/1/2010 8:26       3.39     17850.0  United Kingdom  20.34
# 2        12/1/2010 8:26       2.75     17850.0  United Kingdom  22.00
# 3        12/1/2010 8:26       3.39     17850.0  United Kingdom  20.34
# 4        12/1/2010 8:26       3.39     17850.0  United Kingdom  20.34
# ...                 ...        ...         ...             ...    ...
# 541904  12/9/2011 12:50       0.85     12680.0          France  10.20
# 541905  12/9/2011 12:50       2.10     12680.0          France  12.60
# 541906  12/9/2011 12:50       4.15     12680.0          France  16.60
# 541907  12/9/2011 12:50       4.15     12680.0          France  16.60
# 541908  12/9/2011 12:50       4.95     12680.0          France  14.85
#
# [541909 rows x 9 columns]

# %% [markdown]
# ** Show total pending amount according to the Countries **

# %%
cn=e.groupby('Country')['Total'].count()
cn.sort_values(ascending=False)
# Out:
# Country
# United Kingdom          495478
# Germany                   9495
# France                    8557
# EIRE                      8196
# Spain                     2533
# Netherlands               2371
# Belgium                   2069
# Switzerland               2002
# Portugal                  1519
# Australia                 1259
# Norway                    1086
# Italy                      803
# Channel Islands            758
# Finland                    695
# Cyprus                     622
# Sweden                     462
# Unspecified                446
# Austria                    401
# Denmark                    389
# Japan                      358
# Poland                     341
# Israel                     297
# USA                        291
# Hong Kong                  288
# Singapore                  229
# Iceland                    182
# Canada                     151
# Greece                     146
# Malta                      127
# United Arab Emirates        68
# European Community          61
# RSA                         58
# Lebanon                     45
# Lithuania                   35
# Brazil                      32
# Czech Republic              30
# Bahrain                     19
# Saudi Arabia                10
# Name: Total, dtype: int64

# %% [markdown]
# ** Which Country spend least? **

# %%
pd.DataFrame(e.groupby('Country')['Total'].sum().sort_values(ascending=True).head(1))
# Out:
#                Total
# Country
# Saudi Arabia  131.17

# %% [markdown]
# ** Calculate average of spending according to country with apply function? **

# %%
e.groupby('Country')['Total'].apply(np.mean).sort_values()
# Out:
# Country
# USA                       5.948179
# Unspecified              10.649753
# Saudi Arabia             13.117000
# United Kingdom           16.525065
# RSA                      17.281207
# Portugal                 19.333127
# Malta                    19.728110
# Belgium                  19.773301
# Cyprus                   20.813971
# Italy                    21.034259
# Poland                   21.152903
# European Community       21.176230
# Spain                    21.624390
# France                   23.069288
# Germany                  23.348943
# Czech Republic           23.590667
# Iceland                  23.681319
# Canada                   24.280662
# Austria                  25.322494
# Channel Islands          26.499063
# Israel                   26.625657
# United Arab Emirates     27.974706
# Switzerland              28.164510
# Bahrain                  28.863158
# EIRE                     32.122599
# Finland                  32.124806
# Greece                   32.263836
# Norway                   32.378877
# Hong Kong                35.128611
# Brazil                   35.737500
# Lebanon                  37.641778
# Singapore                39.827031
# Lithuania                47.458857
# Denmark                  48.247147
# Sweden                   79.211926
# Japan                    98.716816
# Australia               108.877895
# Netherlands             120.059696
# Name: Total, dtype: float64

# %% [markdown]
# ** Calculate average,mean,max of spending according to country with agg function? **

# %%
e.groupby('Country')['Total'].agg(['mean',max,np.min])
# Out:
#                             mean        max       amin
# Country
# Australia             108.877895    1718.40    -425.00
# Austria                25.322494     360.00     -21.25
# Bahrain                28.863158     205.74    -205.74
# Belgium                19.773301     165.00     -19.95
# Brazil                 35.737500     175.20      15.00
# Canada                 24.280662     550.94       2.50
# Channel Islands        26.499063     408.00    -293.00
# Cyprus                 20.813971     320.69    -320.69
# Czech Republic         23.590667      70.80     -35.76
# Denmark                48.247147     428.40     -59.80
# EIRE                   32.122599    2365.20   -1917.00
# European Community     21.176230      60.00      -8.50
# Finland                32.124806     551.20     -80.00
# France                 23.069288    4161.06   -8322.12
# Germany                23.348943     876.00    -599.50
# Greece                 32.263836     175.20     -50.00
# Hong Kong              35.128611    2653.95   -2653.95
# Iceland                23.681319     249.60       5.04
# Israel                 26.625657     350.40    -136.00
# Italy                  21.034259     300.00     -89.55

# Out:
#        InvoiceNo StockCode                        Description  Quantity  \
# 6421      536944     22383            LUNCH BAG SUKI  DESIGN         70
# 6422      536944     22384            LUNCH BAG PINK POLKADOT       100
# 6423      536944     20727            LUNCH BAG  BLACK SKULL.        60
# 6424      536944     20725            LUNCH BAG RED RETROSPOT        70
# 6425      536944     20728                LUNCH BAG CARS BLUE       100
# ...          ...       ...                                ...       ...
# 495924    578339    47567B             TEA TIME KITCHEN APRON         6
# 495926    578339     21907          I'M ON HOLIDAY METAL SIGN        12
# 495928    578339      POST                            POSTAGE         1
# 531430    580955     21121  SET/10 RED POLKADOT PARTY CANDLES        24
# 531431    580955      POST                            POSTAGE         1
#
#             InvoiceDate  UnitPrice  CustomerID Country  Total
# 6421    12/3/2010 12:20       1.65     12557.0   Spain  115.5
# 6422    12/3/2010 12:20       1.45     12557.0   Spain  145.0
# 6423    12/3/2010 12:20       1.65     12557.0   Spain   99.0
# 6424    12/3/2010 12:20       1.65     12557.0   Spain  115.5
# 6425    12/3/2010 12:20       1.45     12557.0   Spain  145.0
# ...                 ...        ...         ...     ...    ...
# 495924  11/24/2011 9:07       5.95     12421.0   Spain   35.7
# 495926  11/24/2011 9:07       2.10     12421.0   Spain   25.2
# 495928  11/24/2011 9:07      28.00     12421.0   Spain   28.0
# 531430  12/6/2011 14:22       1.25     12442.0   Spain   30.0
# 531431  12/6/2011 14:22      28.00     12442.0   Spain   28.0
#
# [728 rows x 9 columns]

# %% [markdown]
# ** Convert datatype of InvoiceDate to datetime and assign it to new column name InvoiceDate2**

# %%
e.InvoiceDate.dtype
# Out:
# dtype('O')

# %%
pd.to_datetime(e.InvoiceDate)[0]
# Out:
# Timestamp('2010-12-01 08:26:00')

# %%
e['InvoiceDate2']=pd.to_datetime(e.InvoiceDate)
e
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country  Total  \
# 0        12/1/2010 8:26       2.55     17850.0  United Kingdom  15.30
# 1        12/1/2010 8:26       3.39     17850.0  United Kingdom  20.34
# 2        12/1/2010 8:26       2.75     17850.0  United Kingdom  22.00
# 3        12/1/2010 8:26       3.39     17850.0  United Kingdom  20.34
# 4        12/1/2010 8:26       3.39     17850.0  United Kingdom  20.34
# ...                 ...        ...         ...             ...    ...
# 541904  12/9/2011 12:50       0.85     12680.0          France  10.20
# 541905  12/9/2011 12:50       2.10     12680.0          France  12.60
# 541906  12/9/2011 12:50       4.15     12680.0          France  16.60
# 541907  12/9/2011 12:50       4.15     12680.0          France  16.60
# 541908  12/9/2011 12:50       4.95     12680.0          France  14.85
#
#               InvoiceDate2
# 0      2010-12-01 08:26:00
# 1      2010-12-01 08:26:00
# 2      2010-12-01 08:26:00
# 3      2010-12-01 08:26:00
# 4      2010-12-01 08:26:00
# ...                    ...
# 541904 2011-12-09 12:50:00
# 541905 2011-12-09 12:50:00
# 541906 2011-12-09 12:50:00
# 541907 2011-12-09 12:50:00
# 541908 2011-12-09 12:50:00
#
# [541909 rows x 10 columns]

# %%
e.InvoiceData2.astype(datetime)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-3d03a2e3edb5> in <module>
# ----> 1 e.InvoiceData2.astype(datetime)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'InvoiceData2'

# %% [markdown]
# ** Take only date values (year-month-day) from InvoiceDate2 and assign it to a new column named date **

# %%
e['date']=e.InvoiceDate2.dt.date

# %%
e.head()

# %%
e.InvoiceDate2.dtype

# %%
e.dtypes

# %% [markdown]
# ** drop InvoiceDate2 and InvoiceDate columns permanently **

# %%
e.drop(['InvoiceDate2','InvoiceDate'],axis=1,inplace=True)
e

# %% [markdown]
# ** Remove A, B, G and E from first 5 rows of ecom dataframe with a string method **

# %%
e.StockCode[:5].str.replace("A",'').str.replace("B",'').str.replace("E",'').str.replace("G",'')

# %%
f=e.StockCode[:5].copy()
def rep(f):
    return f.replace("A",'').replace("B",'').replace("E",'').replace("G",'')
f.apply(lambda x: rep(x))

# %% [markdown]
# ** take only Total and date columns with loc and craete a new df named ecom2 **

# %%
e2=e.loc[:,['Total','date']].head()
e2.head(1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-26-98d508763a47> in <module>
# ----> 1 e2=e.loc[:,['Total','date']].head()
#       2 e2.head(1)
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     887                     # AttributeError for IntervalTree get_value
#     888                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 889             return self._getitem_tuple(key)
#     890         else:
#     891             # we by definition only have the 0th axis
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    1067             return self._multi_take(tup)
#    1068
# -> 1069         return self._getitem_tuple_same_dim(tup)
#    1070
#    1071     def _get_label(self, label, axis: int):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple_same_dim(self, tup)
#     773                 continue
#     774
# --> 775             retval = getattr(retval, self.name)._getitem_axis(key, axis=i)
#     776             # We should never have retval.ndim < self.ndim, as that should
#     777             #  be handled by the _getitem_lowerdim call above.
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1111                     raise ValueError("Cannot index with multidimensional key")
#    1112
# -> 1113                 return self._getitem_iterable(key, axis=axis)
#    1114
#    1115             # nested tuple slicing
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_iterable(self, key, axis)
#    1051
#    1052         # A collection of keys
# -> 1053         keyarr, indexer = self._get_listlike_indexer(key, axis, raise_missing=False)
#    1054         return self.obj._reindex_with_indexers(
#    1055             {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1264             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1265
# -> 1266         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1267         return keyarr, indexer
#    1268
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1319
#    1320             with option_context("display.max_seq_items", 10, "display.width", 80):
# -> 1321                 raise KeyError(
#    1322                     "Passing list-likes to .loc or [] with any missing labels "
#    1323                     "is no longer supported. "
#
# KeyError: "Passing list-likes to .loc or [] with any missing labels is no longer supported. The following labels were missing: Index(['date'], dtype='object'). See https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#deprecate-loc-reindex-listlike"

# %% [markdown]
# ** take only InvoiceNo, CustomerID and Total columns with iloc and craete a new df named ecom3 **

# %%
e.iloc[:, [0,7,5]]

# %% [markdown]
# ** Combine ecom2 and ecom3 with concat **

# %%
e3=e.iloc[:,[0,7,5]]

# %%
pd.concat([e2,e3],axis=1)

# %% [markdown]
# ** Combine ecom2 and ecom3 with merge **

# %%
print(e2.columns)
print(e3.columns)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-e3a22340fe7f> in <module>
# ----> 1 print(e2.columns)
#       2 print(e3.columns)
#
# NameError: name 'e2' is not defined

# %%
pd.merge(e2,e3,how='inner',on='Total').head(2)

# %% [markdown]
# ** Combine ecom2 and ecom3 with join **

# %%
e2.join(e3,how='inner', lsuffix='quinn_left',rsuffix='quinn_right')

# %% [markdown]
# # Congrats!
